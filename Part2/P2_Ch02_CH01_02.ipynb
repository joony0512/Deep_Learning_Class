# %% [markdown]
# <a href="https://colab.research.google.com/github/joony0512/Deep_Learning_Class/blob/main/Part2/P2_Ch02_CH01_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

function_x = np.linspace(-3,3,100)
function_y = function_x**3

fig, ax = plt.subplots(figsize = (10,5))
ax.plot(function_x, function_y)

x = 3
y = x**3
ax.scatter(x,y, color = 'red', s = 300)
lr = 0.01

for _ in range(30):
  dy_dx = 3*x**2
  x = x - lr*dy_dx
  y = x**3

  ax.scatter(x, y, color = 'red', s = 100)
