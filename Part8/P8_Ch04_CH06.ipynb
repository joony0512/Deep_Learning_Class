# %% [markdown]
# <a href="https://colab.research.google.com/github/joony0512/Deep_Learning_Class/blob/main/Part8/P8_Ch04_CH06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nbformat==5.8.0
# !pip install nbconvert==7.3.1

# %% [markdown]
# # 흑백 -> 컬러이미지 Colorization Task

# %% [markdown]
#   ![PFCN dataset](https://www.researchgate.net/profile/Dawei_Li49/publication/334417334/figure/fig4/AS:832930272276492@1575597460956/Sample-images-from-the-PFCN-dataset.jpg)
#
#      위의 이미지는 다음과 같은 것을 보여줍니다.
#     - 800x600의 사람 portrait 이미지
#      - ?????.png
#     - 사람 영역에 대한 흑백 portrait 이미지
#      - ?????_matte.png
#     - pfcn_original
#      - 원본 800x600 이미지들
#     - pfcn_small
#      - colab용 100x75 이미지들
#
#
#
# - 데이터 출처:
#  - [PFCN dataset](https://1drv.ms/u/s!ApwdOxIIFBH19Ts5EuFd9gVJrKTo)
#  - [pfcn_small](https://drive.google.com/file/d/1_q37TRIFwtwhmSeLu_4h3SkFHrDSjeyl/view?usp=sharing)

# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import Dense
from keras.models import Sequential

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from IPython.display import Image

warnings.filterwarnings('ignore')
# %matplotlib inline

SEED = 34

# %% [markdown]
# # 1. EDA

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount = True)
# Out:
# Mounted at /gdrive

# %%
# !ls -al /gdrive/MyDrive/딥러닝_정주행/P8_Ch02.인물사진에서배경없애기
# Out:
# total 161695
# -rw------- 1 root root  23713432 Oct 23 10:41 lecture003.h5
# -rw------- 1 root root   4572521 Oct 23 10:46 P8_Ch02_CH06,07.ipynb
# -rw------- 1 root root 137288603 Oct 12 07:20 pfcn_small.npz

# %%
pfcn_small = np.load('/gdrive/MyDrive/딥러닝_정주행/P8_Ch02.인물사진에서배경없애기/pfcn_small.npz')

# %%
print(list(pfcn_small.keys()))

train_images = pfcn_small['train_images']
test_images = pfcn_small['test_images']
# Out:
# ['train_images', 'test_images', 'train_mattes', 'test_mattes']

# %%
train_images[train_images !=0][:10]
# Out:
# array([0.23627451, 0.34803922, 0.64705882, 0.24509804, 0.35686275,
#        0.65588235, 0.25490196, 0.36470588, 0.66470588, 0.2372549 ])

# %%
print(train_images.dtype)
print(len(train_images))
# Out:
# float64
# 1700

# %%
print(train_images.shape, test_images.shape)
print(len(train_images), len(test_images))
# Out:
# (1700, 100, 75, 3) (300, 100, 75, 3)
# 1700 300

# %%
train_images[train_images !=0]
# Out:
# array([0.23627451, 0.34803922, 0.64705882, ..., 0.05588235, 0.0245098 ,
#        0.01470588])

# %%
train_images.dtype, test_images.dtype
# Out:
# (dtype('float64'), dtype('float64'))

# %%
print(train_images.min())
print(train_images.max())

print('----------------')
print(test_images.min())
print(test_images.max())
# Out:
# 0.0
# 1.0
# ----------------
# 0.0
# 1.0

# %% [markdown]
# # 2. 전처리

# %% [markdown]
# - train_gray_images, test_gray_images 생성

# %%
from skimage import color

train_gray_images = np.array([color.rgb2gray(img).reshape((100, 75, 1)) for img in train_images])
test_gray_images = np.array([color.rgb2gray(img).reshape((100, 75, 1)) for img in test_images])


print(train_gray_images.shape, test_gray_images.shape)
# Out:
# (1700, 100, 75, 1) (300, 100, 75, 1)

# %%
plt.imshow(train_images[0])

# %%
plt.imshow(train_gray_images[0], cmap ='gray')

# %% [markdown]
# # 3. Visualization

# %%
train_images[:5].shape, train_gray_images[:5].shape
# Out:
# ((5, 100, 75, 3), (5, 100, 75, 1))

# %%
five = train_images[:5].transpose((1,0,2,3)).reshape((100,-1, 3))

# %%
plt.imshow(five)

# %%
five_gray = train_gray_images[:5].transpose((1,0,2,3)).reshape((100,-1))

# %%
plt.imshow(five_gray, cmap ='gray')

# %% [markdown]
# # 4. 흑백 -> 컬러 모델링
# - (100, 75, 1) -> (100, 75, 3)

# %%
from tensorflow import keras
from keras.layers import Dense, Input, Conv2D, Conv2DTranspose, Flatten
from keras.layers import Reshape, MaxPool2D
from keras.models import Model
from keras.layers import BatchNormalization, Dropout, Activation, concatenate

# %%
def conv2d_block(x, channel):
    x = Conv2D(channel, 3, padding = 'same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(channel, 3, padding = 'same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    return x

def unet_color():
    inputs = Input((100, 75, 1))

    c1 = conv2d_block(inputs, 16)
    p1 = MaxPool2D(2)(c1)
    p1 = Dropout(0.1)(p1)

    c2 = conv2d_block(p1, 32)
    p2 = MaxPool2D(2)(c2)
    p2 = Dropout(0.1)(p2)

    c3 = conv2d_block(p2, 64)
    p3 = MaxPool2D(2)(c3)
    p3 = Dropout(0.1)(p3)

    c4 = conv2d_block(p3, 128)
    p4 = MaxPool2D(2)(c4)
    p4 = Dropout(0.1)(p4)

    c5 = conv2d_block(p4, 256)

    u6 = Conv2DTranspose(128, 2, 2, padding = 'valid', output_padding= (0,1))(c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(0.1)(u6)
    c6 = conv2d_block(u6, 128)

    u7 = Conv2DTranspose(64, 2, 2, padding = 'valid', output_padding= (1,0))(c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(0.1)(u7)
    c7 = conv2d_block(u7, 64)

    u8 = Conv2DTranspose(32, 2, 2, padding = 'valid', output_padding= (0,1))(c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(0.1)(u8)
    c8 = conv2d_block(u8, 32)

    u9 = Conv2DTranspose(16, 2, 2, padding = 'valid', output_padding= (0,1))(c8)
    u9 = concatenate([u9, c1])
    u9 = Dropout(0.1)(u9)
    c9 = conv2d_block(u9, 16)

    outputs = Conv2D(3, 1, activation ='sigmoid')(c9)

    model = Model(inputs, outputs)

    return model

# %%
model = unet_color()

model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 100, 75, 1)]         0         []
#
#  conv2d_38 (Conv2D)          (None, 100, 75, 16)          160       ['input_3[0][0]']
#
#  batch_normalization_36 (Ba  (None, 100, 75, 16)          64        ['conv2d_38[0][0]']
#  tchNormalization)
#
#  activation_36 (Activation)  (None, 100, 75, 16)          0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  conv2d_39 (Conv2D)          (None, 100, 75, 16)          2320      ['activation_36[0][0]']
#
#  batch_normalization_37 (Ba  (None, 100, 75, 16)          64        ['conv2d_39[0][0]']
#  tchNormalization)
#
#  activation_37 (Activation)  (None, 100, 75, 16)          0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  max_pooling2d_8 (MaxPoolin  (None, 50, 37, 16)           0         ['activation_37[0][0]']
#  g2D)
#
#  dropout_16 (Dropout)        (None, 50, 37, 16)           0         ['max_pooling2d_8[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 50, 37, 32)           4640      ['dropout_16[0][0]']
#
#  batch_normalization_38 (Ba  (None, 50, 37, 32)           128       ['conv2d_40[0][0]']
#  tchNormalization)
#
#  activation_38 (Activation)  (None, 50, 37, 32)           0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  conv2d_41 (Conv2D)          (None, 50, 37, 32)           9248      ['activation_38[0][0]']
#
#  batch_normalization_39 (Ba  (None, 50, 37, 32)           128       ['conv2d_41[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 50, 37, 32)           0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  max_pooling2d_9 (MaxPoolin  (None, 25, 18, 32)           0         ['activation_39[0][0]']
#  g2D)
#
#  dropout_17 (Dropout)        (None, 25, 18, 32)           0         ['max_pooling2d_9[0][0]']
#
#  conv2d_42 (Conv2D)          (None, 25, 18, 64)           18496     ['dropout_17[0][0]']
#
#  batch_normalization_40 (Ba  (None, 25, 18, 64)           256       ['conv2d_42[0][0]']
#  tchNormalization)
#
#  activation_40 (Activation)  (None, 25, 18, 64)           0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 25, 18, 64)           36928     ['activation_40[0][0]']
#
#  batch_normalization_41 (Ba  (None, 25, 18, 64)           256       ['conv2d_43[0][0]']
#  tchNormalization)
#
#  activation_41 (Activation)  (None, 25, 18, 64)           0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  max_pooling2d_10 (MaxPooli  (None, 12, 9, 64)            0         ['activation_41[0][0]']
#  ng2D)
#
#  dropout_18 (Dropout)        (None, 12, 9, 64)            0         ['max_pooling2d_10[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 12, 9, 128)           73856     ['dropout_18[0][0]']
#
#  batch_normalization_42 (Ba  (None, 12, 9, 128)           512       ['conv2d_44[0][0]']
#  tchNormalization)
#
#  activation_42 (Activation)  (None, 12, 9, 128)           0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  conv2d_45 (Conv2D)          (None, 12, 9, 128)           147584    ['activation_42[0][0]']
#
#  batch_normalization_43 (Ba  (None, 12, 9, 128)           512       ['conv2d_45[0][0]']
#  tchNormalization)
#
#  activation_43 (Activation)  (None, 12, 9, 128)           0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  max_pooling2d_11 (MaxPooli  (None, 6, 4, 128)            0         ['activation_43[0][0]']
#  ng2D)
#
#  dropout_19 (Dropout)        (None, 6, 4, 128)            0         ['max_pooling2d_11[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 6, 4, 256)            295168    ['dropout_19[0][0]']
#
#  batch_normalization_44 (Ba  (None, 6, 4, 256)            1024      ['conv2d_46[0][0]']
#  tchNormalization)
#
#  activation_44 (Activation)  (None, 6, 4, 256)            0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  conv2d_47 (Conv2D)          (None, 6, 4, 256)            590080    ['activation_44[0][0]']
#
#  batch_normalization_45 (Ba  (None, 6, 4, 256)            1024      ['conv2d_47[0][0]']
#  tchNormalization)
#
#  activation_45 (Activation)  (None, 6, 4, 256)            0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_transpose_8 (Conv2D  (None, 12, 9, 128)           131200    ['activation_45[0][0]']
#  Transpose)
#
#  concatenate_8 (Concatenate  (None, 12, 9, 256)           0         ['conv2d_transpose_8[0][0]',
#  )                                                                   'activation_43[0][0]']
#
#  dropout_20 (Dropout)        (None, 12, 9, 256)           0         ['concatenate_8[0][0]']
#
#  conv2d_48 (Conv2D)          (None, 12, 9, 128)           295040    ['dropout_20[0][0]']
#
#  batch_normalization_46 (Ba  (None, 12, 9, 128)           512       ['conv2d_48[0][0]']
#  tchNormalization)
#
#  activation_46 (Activation)  (None, 12, 9, 128)           0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 12, 9, 128)           147584    ['activation_46[0][0]']
#
#  batch_normalization_47 (Ba  (None, 12, 9, 128)           512       ['conv2d_49[0][0]']
#  tchNormalization)
#
#  activation_47 (Activation)  (None, 12, 9, 128)           0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  conv2d_transpose_9 (Conv2D  (None, 25, 18, 64)           32832     ['activation_47[0][0]']
#  Transpose)
#
#  concatenate_9 (Concatenate  (None, 25, 18, 128)          0         ['conv2d_transpose_9[0][0]',
#  )                                                                   'activation_41[0][0]']
#
#  dropout_21 (Dropout)        (None, 25, 18, 128)          0         ['concatenate_9[0][0]']
#
#  conv2d_50 (Conv2D)          (None, 25, 18, 64)           73792     ['dropout_21[0][0]']
#
#  batch_normalization_48 (Ba  (None, 25, 18, 64)           256       ['conv2d_50[0][0]']
#  tchNormalization)
#
#  activation_48 (Activation)  (None, 25, 18, 64)           0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  conv2d_51 (Conv2D)          (None, 25, 18, 64)           36928     ['activation_48[0][0]']
#
#  batch_normalization_49 (Ba  (None, 25, 18, 64)           256       ['conv2d_51[0][0]']
#  tchNormalization)
#
#  activation_49 (Activation)  (None, 25, 18, 64)           0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  conv2d_transpose_10 (Conv2  (None, 50, 37, 32)           8224      ['activation_49[0][0]']
#  DTranspose)
#
#  concatenate_10 (Concatenat  (None, 50, 37, 64)           0         ['conv2d_transpose_10[0][0]',
#  e)                                                                  'activation_39[0][0]']
#
#  dropout_22 (Dropout)        (None, 50, 37, 64)           0         ['concatenate_10[0][0]']
#
#  conv2d_52 (Conv2D)          (None, 50, 37, 32)           18464     ['dropout_22[0][0]']
#
#  batch_normalization_50 (Ba  (None, 50, 37, 32)           128       ['conv2d_52[0][0]']
#  tchNormalization)
#
#  activation_50 (Activation)  (None, 50, 37, 32)           0         ['batch_normalization_50[0][0]
#                                                                     ']
#
#  conv2d_53 (Conv2D)          (None, 50, 37, 32)           9248      ['activation_50[0][0]']
#
#  batch_normalization_51 (Ba  (None, 50, 37, 32)           128       ['conv2d_53[0][0]']
#  tchNormalization)
#
#  activation_51 (Activation)  (None, 50, 37, 32)           0         ['batch_normalization_51[0][0]
#                                                                     ']
#
#  conv2d_transpose_11 (Conv2  (None, 100, 75, 16)          2064      ['activation_51[0][0]']
#  DTranspose)
#
#  concatenate_11 (Concatenat  (None, 100, 75, 32)          0         ['conv2d_transpose_11[0][0]',
#  e)                                                                  'activation_37[0][0]']
#
#  dropout_23 (Dropout)        (None, 100, 75, 32)          0         ['concatenate_11[0][0]']
#
#  conv2d_54 (Conv2D)          (None, 100, 75, 16)          4624      ['dropout_23[0][0]']
#
#  batch_normalization_52 (Ba  (None, 100, 75, 16)          64        ['conv2d_54[0][0]']
#  tchNormalization)
#
#  activation_52 (Activation)  (None, 100, 75, 16)          0         ['batch_normalization_52[0][0]
#                                                                     ']
#
#  conv2d_55 (Conv2D)          (None, 100, 75, 16)          2320      ['activation_52[0][0]']
#
#  batch_normalization_53 (Ba  (None, 100, 75, 16)          64        ['conv2d_55[0][0]']
#  tchNormalization)
#
#  activation_53 (Activation)  (None, 100, 75, 16)          0         ['batch_normalization_53[0][0]
#                                                                     ']
#
#  conv2d_56 (Conv2D)          (None, 100, 75, 3)           51        ['activation_53[0][0]']
#
# ==================================================================================================
# Total params: 1946739 (7.43 MB)
# Trainable params: 1943795 (7.41 MB)
# Non-trainable params: 2944 (11.50 KB)
# __________________________________________________________________________________________________

# %%
model.compile(loss = 'mae', optimizer = 'adam', metrics =['accuracy'])

# %%
hist2 = model.fit(train_gray_images, train_images, validation_data =[test_gray_images, test_images], epochs =50, verbose =1)
# Out:
# Epoch 1/50
# 54/54 [==============================] - 5s 83ms/step - loss: 0.0528 - accuracy: 0.6639 - val_loss: 0.0560 - val_accuracy: 0.6235
# Epoch 2/50
# 54/54 [==============================] - 4s 69ms/step - loss: 0.0524 - accuracy: 0.6663 - val_loss: 0.0549 - val_accuracy: 0.6793
# Epoch 3/50
# 54/54 [==============================] - 4s 75ms/step - loss: 0.0517 - accuracy: 0.6716 - val_loss: 0.0498 - val_accuracy: 0.6684
# Epoch 4/50
# 54/54 [==============================] - 4s 73ms/step - loss: 0.0522 - accuracy: 0.6770 - val_loss: 0.0508 - val_accuracy: 0.6560
# Epoch 5/50
# 54/54 [==============================] - 4s 66ms/step - loss: 0.0508 - accuracy: 0.6726 - val_loss: 0.0498 - val_accuracy: 0.6537
# Epoch 6/50
# 54/54 [==============================] - 4s 65ms/step - loss: 0.0501 - accuracy: 0.6850 - val_loss: 0.0495 - val_accuracy: 0.6794
# Epoch 7/50
# 54/54 [==============================] - 4s 69ms/step - loss: 0.0494 - accuracy: 0.6856 - val_loss: 0.0487 - val_accuracy: 0.6750
# Epoch 8/50
# 54/54 [==============================] - 4s 69ms/step - loss: 0.0491 - accuracy: 0.6834 - val_loss: 0.0503 - val_accuracy: 0.6794
# Epoch 9/50
# 54/54 [==============================] - 4s 66ms/step - loss: 0.0487 - accuracy: 0.6872 - val_loss: 0.0518 - val_accuracy: 0.6408
# Epoch 10/50
# 54/54 [==============================] - 4s 66ms/step - loss: 0.0494 - accuracy: 0.6912 - val_loss: 0.0506 - val_accuracy: 0.6306
# Epoch 11/50
# 54/54 [==============================] - 4s 66ms/step - loss: 0.0478 - accuracy: 0.6926 - val_loss: 0.0506 - val_accuracy: 0.6368
# Epoch 12/50
# 54/54 [==============================] - 4s 69ms/step - loss: 0.0479 - accuracy: 0.6947 - val_loss: 0.0518 - val_accuracy: 0.6512
# Epoch 13/50
# 54/54 [==============================] - 4s 67ms/step - loss: 0.0456 - accuracy: 0.7005 - val_loss: 0.0564 - val_accuracy: 0.6216
# Epoch 14/50
# 54/54 [==============================] - 4s 65ms/step - loss: 0.0455 - accuracy: 0.6968 - val_loss: 0.0492 - val_accuracy: 0.6616
# Epoch 15/50
# 54/54 [==============================] - 4s 65ms/step - loss: 0.0450 - accuracy: 0.7075 - val_loss: 0.0524 - val_accuracy: 0.6655
# Epoch 16/50
# 54/54 [==============================] - 4s 67ms/step - loss: 0.0442 - accuracy: 0.7054 - val_loss: 0.0535 - val_accuracy: 0.6483
# Epoch 17/50
# 54/54 [==============================] - 4s 68ms/step - loss: 0.0450 - accuracy: 0.7068 - val_loss: 0.0580 - val_accuracy: 0.5927
# Epoch 18/50
# 54/54 [==============================] - 4s 65ms/step - loss: 0.0453 - accuracy: 0.7058 - val_loss: 0.0498 - val_accuracy: 0.6743
# Epoch 19/50
# 54/54 [==============================] - 4s 65ms/step - loss: 0.0434 - accuracy: 0.7063 - val_loss: 0.0518 - val_accuracy: 0.6571
# Epoch 20/50
# 54/54 [==============================] - 4s 70ms/step - loss: 0.0444 - accuracy: 0.7035 - val_loss: 0.0514 - val_accuracy: 0.6890
# Epoch 21/50
# 54/54 [==============================] - 4s 68ms/step - loss: 0.0428 - accuracy: 0.7135 - val_loss: 0.0532 - val_accuracy: 0.6334
# Epoch 22/50
# 54/54 [==============================] - 4s 66ms/step - loss: 0.0434 - accuracy: 0.7176 - val_loss: 0.0484 - val_accuracy: 0.6730
# Epoch 23/50
# 54/54 [==============================] - 4s 65ms/step - loss: 0.0427 - accuracy: 0.7165 - val_loss: 0.0486 - val_accuracy: 0.6652
# Epoch 24/50
# 54/54 [==============================] - 3s 65ms/step - loss: 0.0438 - accuracy: 0.7125 - val_loss: 0.0554 - val_accuracy: 0.6507
# Epoch 25/50
# 54/54 [==============================] - 4s 67ms/step - loss: 0.0410 - accuracy: 0.7134 - val_loss: 0.0486 - val_accuracy: 0.6601
# Epoch 26/50
# 54/54 [==============================] - 4s 68ms/step - loss: 0.0416 - accuracy: 0.7116 - val_loss: 0.0481 - val_accuracy: 0.6534
# Epoch 27/50
# 54/54 [==============================] - 4s 65ms/step - loss: 0.0409 - accuracy: 0.7141 - val_loss: 0.0489 - val_accuracy: 0.6719
# Epoch 28/50
# 54/54 [==============================] - 4s 66ms/step - loss: 0.0404 - accuracy: 0.7225 - val_loss: 0.0496 - val_accuracy: 0.6689
# Epoch 29/50
# 54/54 [==============================] - 4s 67ms/step - loss: 0.0406 - accuracy: 0.7169 - val_loss: 0.0497 - val_accuracy: 0.6588
# Epoch 30/50
# 54/54 [==============================] - 4s 69ms/step - loss: 0.0397 - accuracy: 0.7213 - val_loss: 0.0489 - val_accuracy: 0.6282
# Epoch 31/50
# 54/54 [==============================] - 4s 66ms/step - loss: 0.0397 - accuracy: 0.7193 - val_loss: 0.0490 - val_accuracy: 0.6230
# Epoch 32/50
# 54/54 [==============================] - 4s 66ms/step - loss: 0.0399 - accuracy: 0.7295 - val_loss: 0.0524 - val_accuracy: 0.6284
# Epoch 33/50
# 54/54 [==============================] - 4s 67ms/step - loss: 0.0398 - accuracy: 0.7263 - val_loss: 0.0586 - val_accuracy: 0.6832
# Epoch 34/50
# 54/54 [==============================] - 4s 73ms/step - loss: 0.0398 - accuracy: 0.7237 - val_loss: 0.0492 - val_accuracy: 0.6573
# Epoch 35/50
# 54/54 [==============================] - 4s 67ms/step - loss: 0.0381 - accuracy: 0.7297 - val_loss: 0.0535 - val_accuracy: 0.6647
# Epoch 36/50
# 54/54 [==============================] - 4s 66ms/step - loss: 0.0389 - accuracy: 0.7265 - val_loss: 0.0480 - val_accuracy: 0.6428
# Epoch 37/50
# 54/54 [==============================] - 4s 66ms/step - loss: 0.0383 - accuracy: 0.7293 - val_loss: 0.0507 - val_accuracy: 0.6804
# Epoch 38/50
# 54/54 [==============================] - 4s 69ms/step - loss: 0.0366 - accuracy: 0.7379 - val_loss: 0.0493 - val_accuracy: 0.6652
# Epoch 39/50
# 54/54 [==============================] - 4s 67ms/step - loss: 0.0372 - accuracy: 0.7336 - val_loss: 0.0492 - val_accuracy: 0.6716
# Epoch 40/50
# 54/54 [==============================] - 4s 65ms/step - loss: 0.0369 - accuracy: 0.7375 - val_loss: 0.0473 - val_accuracy: 0.6633
# Epoch 41/50
# 54/54 [==============================] - 4s 66ms/step - loss: 0.0362 - accuracy: 0.7343 - val_loss: 0.0486 - val_accuracy: 0.6596
# Epoch 42/50
# 54/54 [==============================] - 4s 68ms/step - loss: 0.0377 - accuracy: 0.7342 - val_loss: 0.0548 - val_accuracy: 0.6699
# Epoch 43/50
# 54/54 [==============================] - 4s 69ms/step - loss: 0.0373 - accuracy: 0.7375 - val_loss: 0.0469 - val_accuracy: 0.6460
# Epoch 44/50
# 54/54 [==============================] - 4s 66ms/step - loss: 0.0366 - accuracy: 0.7419 - val_loss: 0.0488 - val_accuracy: 0.6655
# Epoch 45/50
# 54/54 [==============================] - 4s 65ms/step - loss: 0.0361 - accuracy: 0.7435 - val_loss: 0.0474 - val_accuracy: 0.6582
# Epoch 46/50
# 54/54 [==============================] - 4s 67ms/step - loss: 0.0356 - accuracy: 0.7477 - val_loss: 0.0467 - val_accuracy: 0.6736
# Epoch 47/50
# 54/54 [==============================] - 4s 69ms/step - loss: 0.0348 - accuracy: 0.7515 - val_loss: 0.0462 - val_accuracy: 0.6472
# Epoch 48/50
# 54/54 [==============================] - 4s 67ms/step - loss: 0.0356 - accuracy: 0.7448 - val_loss: 0.0478 - val_accuracy: 0.6485
# Epoch 49/50
# 54/54 [==============================] - 4s 66ms/step - loss: 0.0352 - accuracy: 0.7515 - val_loss: 0.0468 - val_accuracy: 0.6589
# Epoch 50/50
# 54/54 [==============================] - 4s 66ms/step - loss: 0.0342 - accuracy: 0.7463 - val_loss: 0.0485 - val_accuracy: 0.6701

# %%
plt.plot(hist2.history['accuracy'], label = 'accuracy')
plt.plot(hist2.history['loss'], label = 'loss')
plt.plot(hist2.history['val_accuracy'], label = 'val_accuracy')
plt.plot(hist2.history['val_loss'], label = 'val_loss')

plt.legend(loc = 'upper left')
plt.show()

# %%
plt.plot(hist2.history['accuracy'], label = 'accuracy')
plt.plot(hist2.history['loss'], label = 'loss')
plt.plot(hist2.history['val_accuracy'], label = 'val_accuracy')
plt.plot(hist2.history['val_loss'], label = 'val_loss')

plt.legend(loc = 'upper left')
plt.show()

# %% [markdown]
# # 5. Colorization 모델 결과 확인

# %%
res = model.predict(test_gray_images[0:1])
# Out:
# 1/1 [==============================] - 1s 974ms/step

# %%
print((test_gray_images[0:1]).shape)
print(res.shape)
# Out:
# (1, 100, 75, 1)
# (1, 100, 75, 3)

# %%
plt.imshow(test_gray_images[0], cmap ='gray')

# %%
plt.imshow(np.concatenate([res[0], test_images[0]], axis = 1))

# %%
plt.imshow(test_gray_images[1], cmap = 'gray')

# %%
res = model.predict(test_gray_images[1:2])
# Out:
# 1/1 [==============================] - 0s 36ms/step

# %%
plt.imshow(np.concatenate([res[0], test_images[1]], axis = 1))

# %%
# 10 Epochs
five = model.predict(test_gray_images[:5])
plt.imshow(np.concatenate([five, test_images[:5]], axis =2).reshape((-1, 150, 3)))
# Out:
# 1/1 [==============================] - 0s 403ms/step

# %%
# 50 Epochs -> 10epoch 보다 더 세피아톤
five = model.predict(test_gray_images[:5])
plt.imshow(np.concatenate([five, test_images[:5]], axis =2).reshape((-1, 150, 3)))
# Out:
# 1/1 [==============================] - 0s 20ms/step

# %% [markdown]
# - 전반적으로 살색은 잘 예측해 보이지만 배경에 대한 색들이 톤다운되어있다.
# - 모델이 오차를 최소화 하는 과정에서 전반적인 배경에 대한 접근이 세피아 톤으로 맞춘것 같다.

# %% [markdown]
# # 6. 모델링 2 : Lab color 로 변경
# - 모든 printer에 대해 보장된 색상으로 변경
# - RGB는 색상을 3채널로 표현, Lab color는 Light (빛) 채널 1개와 Color 채널 2개 (a, b)로 표현한다.
#
# ![image.png](data:image/png;base64,...)

# %%
# rgb -> lab

plt.imshow(test_images[1])

# %%
color.rgb2lab(test_images[1]).shape
# Out:
# (100, 75, 3)

# %%
plt.imshow(color.rgb2lab(test_images[1]))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
train_lab_images = np.array([color.rgb2lab(img) for img in train_images])
test_lab_images = np.array([color.rgb2lab(img) for img in test_images])

# %%
# channel별 최대 최소 확인
print(train_lab_images[..., 0].min(), train_lab_images[..., 0].max())
print(train_lab_images[..., 1].min(), train_lab_images[..., 1].max())
print(train_lab_images[..., 2].min(), train_lab_images[..., 2].max())
# Out:
# 0.0 100.0
# -78.53736435567544 86.20773183914271
# -91.97308466277427 93.80664030542576

# %% [markdown]
# - Lab color를 Normalization

# %%
# lab color는 채널별로 [0~100, -128~+128, -128~+128]을 갖고있다. -> 0-1 normalization

# 1 channel 0~100 에 +0 -> 0~100 -> 100으로 나누기 -> 0~1
# 2 channel -128 ~ +128 에 + 128 -> 0 ~ 255 -> 255로 나누기 -> 0~1
# 3 channel -128 ~ +128 에 + 128 -> 0 ~ 255 -> 255로 나누기 -> 0~1

a = train_lab_images + [0, 128, 128]
print(a[...,0].min(), a[...,0].max())
print(a[...,1].min(), a[...,1].max())
print(a[...,2].min(), a[...,2].max())

b = a / [100, 255, 255]
print(b[...,0].min(), b[...,0].max())
print(b[...,1].min(), b[...,1].max())
print(b[...,2].min(), b[...,2].max())
# Out:
# 0.0 100.0
# 49.462635644324564 214.2077318391427
# 36.02691533722573 221.80664030542576
# 0.0 1.0
# 0.19397112017382181 0.8400303209378145
# 0.141282020930297 0.8698299619820618

# %%
train_lab_images = (train_lab_images + [0, 128, 128]) / [100, 255, 255]
test_lab_images = (test_lab_images + [0, 128, 128]) / [100, 255, 255]

# %%
print(train_lab_images[..., 0].min(), train_lab_images[..., 0].max())
print(train_lab_images[..., 1].min(), train_lab_images[..., 1].max())
print(train_lab_images[..., 2].min(), train_lab_images[..., 2].max())
# Out:
# 0.0 1.0
# 0.19397112017382181 0.8400303209378145
# 0.141282020930297 0.8698299619820618

# %%
train_lab_images[1][...,0].shape
# Out:
# (100, 75)

# %% [markdown]
# - L channel 이 밝기를 담당하기 때문에
#
# - 기존모델 grayscale -> r g b 예측
# - 새로운 모델 L -> a, b예측
#
# - model1(grayscale x) -> rgb
# - model2(L x) -> L x + a + b -> rgb

# %%
plt.imshow(test_lab_images[1][...,0], cmap = 'gray')

# %%
plt.imshow(test_gray_images[1], cmap = 'gray')
plt.show()

# %%
# 흑백 -> lab 컬러 모델링
# (100, 75, 1) -> (100, 75, 2)

def conv2d_block(x, channel):
    x = Conv2D(channel, 3, padding = 'same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(channel, 3, padding = 'same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    return x

def unet_lab():
    inputs = Input((100, 75, 1))

    c1 = conv2d_block(inputs, 16)
    p1 = MaxPool2D(2)(c1)
    p1 = Dropout(0.1)(p1)

    c2 = conv2d_block(p1, 32)
    p2 = MaxPool2D(2)(c2)
    p2 = Dropout(0.1)(p2)

    c3 = conv2d_block(p2, 64)
    p3 = MaxPool2D(2)(c3)
    p3 = Dropout(0.1)(p3)

    c4 = conv2d_block(p3, 128)
    p4 = MaxPool2D(2)(c4)
    p4 = Dropout(0.1)(p4)

    c5 = conv2d_block(p4, 256)

    u6 = Conv2DTranspose(128, 2, 2, padding = 'valid', output_padding= (0,1))(c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(0.1)(u6)
    c6 = conv2d_block(u6, 128)

    u7 = Conv2DTranspose(64, 2, 2, padding = 'valid', output_padding= (1,0))(c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(0.1)(u7)
    c7 = conv2d_block(u7, 64)

    u8 = Conv2DTranspose(32, 2, 2, padding = 'valid', output_padding= (0,1))(c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(0.1)(u8)
    c8 = conv2d_block(u8, 32)

    u9 = Conv2DTranspose(16, 2, 2, padding = 'valid', output_padding= (0,1))(c8)
    u9 = concatenate([u9, c1])
    u9 = Dropout(0.1)(u9)
    c9 = conv2d_block(u9, 16)

    outputs = Conv2D(2, 1, activation ='sigmoid')(c9)

    model = Model(inputs, outputs)

    return model

# %%
model2 = unet_lab()
model2.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 100, 75, 1)]         0         []
#
#  conv2d_19 (Conv2D)          (None, 100, 75, 16)          160       ['input_2[0][0]']
#
#  batch_normalization_18 (Ba  (None, 100, 75, 16)          64        ['conv2d_19[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 100, 75, 16)          0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 100, 75, 16)          2320      ['activation_18[0][0]']
#
#  batch_normalization_19 (Ba  (None, 100, 75, 16)          64        ['conv2d_20[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 100, 75, 16)          0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  max_pooling2d_4 (MaxPoolin  (None, 50, 37, 16)           0         ['activation_19[0][0]']
#  g2D)
#
#  dropout_8 (Dropout)         (None, 50, 37, 16)           0         ['max_pooling2d_4[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 50, 37, 32)           4640      ['dropout_8[0][0]']
#
#  batch_normalization_20 (Ba  (None, 50, 37, 32)           128       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 50, 37, 32)           0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv2d_22 (Conv2D)          (None, 50, 37, 32)           9248      ['activation_20[0][0]']
#
#  batch_normalization_21 (Ba  (None, 50, 37, 32)           128       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 50, 37, 32)           0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  max_pooling2d_5 (MaxPoolin  (None, 25, 18, 32)           0         ['activation_21[0][0]']
#  g2D)
#
#  dropout_9 (Dropout)         (None, 25, 18, 32)           0         ['max_pooling2d_5[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 25, 18, 64)           18496     ['dropout_9[0][0]']
#
#  batch_normalization_22 (Ba  (None, 25, 18, 64)           256       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_22 (Activation)  (None, 25, 18, 64)           0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 25, 18, 64)           36928     ['activation_22[0][0]']
#
#  batch_normalization_23 (Ba  (None, 25, 18, 64)           256       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  activation_23 (Activation)  (None, 25, 18, 64)           0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  max_pooling2d_6 (MaxPoolin  (None, 12, 9, 64)            0         ['activation_23[0][0]']
#  g2D)
#
#  dropout_10 (Dropout)        (None, 12, 9, 64)            0         ['max_pooling2d_6[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 12, 9, 128)           73856     ['dropout_10[0][0]']
#
#  batch_normalization_24 (Ba  (None, 12, 9, 128)           512       ['conv2d_25[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 12, 9, 128)           0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 12, 9, 128)           147584    ['activation_24[0][0]']
#
#  batch_normalization_25 (Ba  (None, 12, 9, 128)           512       ['conv2d_26[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 12, 9, 128)           0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  max_pooling2d_7 (MaxPoolin  (None, 6, 4, 128)            0         ['activation_25[0][0]']
#  g2D)
#
#  dropout_11 (Dropout)        (None, 6, 4, 128)            0         ['max_pooling2d_7[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 6, 4, 256)            295168    ['dropout_11[0][0]']
#
#  batch_normalization_26 (Ba  (None, 6, 4, 256)            1024      ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 6, 4, 256)            0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv2d_28 (Conv2D)          (None, 6, 4, 256)            590080    ['activation_26[0][0]']
#
#  batch_normalization_27 (Ba  (None, 6, 4, 256)            1024      ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 6, 4, 256)            0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_transpose_4 (Conv2D  (None, 12, 9, 128)           131200    ['activation_27[0][0]']
#  Transpose)
#
#  concatenate_4 (Concatenate  (None, 12, 9, 256)           0         ['conv2d_transpose_4[0][0]',
#  )                                                                   'activation_25[0][0]']
#
#  dropout_12 (Dropout)        (None, 12, 9, 256)           0         ['concatenate_4[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 12, 9, 128)           295040    ['dropout_12[0][0]']
#
#  batch_normalization_28 (Ba  (None, 12, 9, 128)           512       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 12, 9, 128)           0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 12, 9, 128)           147584    ['activation_28[0][0]']
#
#  batch_normalization_29 (Ba  (None, 12, 9, 128)           512       ['conv2d_30[0][0]']
#  tchNormalization)
#
#  activation_29 (Activation)  (None, 12, 9, 128)           0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  conv2d_transpose_5 (Conv2D  (None, 25, 18, 64)           32832     ['activation_29[0][0]']
#  Transpose)
#
#  concatenate_5 (Concatenate  (None, 25, 18, 128)          0         ['conv2d_transpose_5[0][0]',
#  )                                                                   'activation_23[0][0]']
#
#  dropout_13 (Dropout)        (None, 25, 18, 128)          0         ['concatenate_5[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 25, 18, 64)           73792     ['dropout_13[0][0]']
#
#  batch_normalization_30 (Ba  (None, 25, 18, 64)           256       ['conv2d_31[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 25, 18, 64)           0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  conv2d_32 (Conv2D)          (None, 25, 18, 64)           36928     ['activation_30[0][0]']
#
#  batch_normalization_31 (Ba  (None, 25, 18, 64)           256       ['conv2d_32[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 25, 18, 64)           0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  conv2d_transpose_6 (Conv2D  (None, 50, 37, 32)           8224      ['activation_31[0][0]']
#  Transpose)
#
#  concatenate_6 (Concatenate  (None, 50, 37, 64)           0         ['conv2d_transpose_6[0][0]',
#  )                                                                   'activation_21[0][0]']
#
#  dropout_14 (Dropout)        (None, 50, 37, 64)           0         ['concatenate_6[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 50, 37, 32)           18464     ['dropout_14[0][0]']
#
#  batch_normalization_32 (Ba  (None, 50, 37, 32)           128       ['conv2d_33[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 50, 37, 32)           0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  conv2d_34 (Conv2D)          (None, 50, 37, 32)           9248      ['activation_32[0][0]']
#
#  batch_normalization_33 (Ba  (None, 50, 37, 32)           128       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 50, 37, 32)           0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  conv2d_transpose_7 (Conv2D  (None, 100, 75, 16)          2064      ['activation_33[0][0]']
#  Transpose)
#
#  concatenate_7 (Concatenate  (None, 100, 75, 32)          0         ['conv2d_transpose_7[0][0]',
#  )                                                                   'activation_19[0][0]']
#
#  dropout_15 (Dropout)        (None, 100, 75, 32)          0         ['concatenate_7[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 100, 75, 16)          4624      ['dropout_15[0][0]']
#
#  batch_normalization_34 (Ba  (None, 100, 75, 16)          64        ['conv2d_35[0][0]']
#  tchNormalization)
#
#  activation_34 (Activation)  (None, 100, 75, 16)          0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 100, 75, 16)          2320      ['activation_34[0][0]']
#
#  batch_normalization_35 (Ba  (None, 100, 75, 16)          64        ['conv2d_36[0][0]']
#  tchNormalization)
#
#  activation_35 (Activation)  (None, 100, 75, 16)          0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 100, 75, 2)           34        ['activation_35[0][0]']
#
# ==================================================================================================
# Total params: 1946722 (7.43 MB)
# Trainable params: 1943778 (7.41 MB)
# Non-trainable params: 2944 (11.50 KB)
# __________________________________________________________________________________________________

# %%
model2.compile(loss = 'mae', optimizer='adam', metrics =['accuracy'])

# %%
hist = model2.fit(train_lab_images[...,0:1], train_lab_images[...,1:3], validation_data = (test_lab_images[...,0:1], test_lab_images[...,1:3]) , epochs = 50, verbose=1)
# Out:
# Epoch 1/50
# 54/54 [==============================] - 4s 80ms/step - loss: 0.0320 - accuracy: 0.6137 - val_loss: 0.0317 - val_accuracy: 0.6229
# Epoch 2/50
# 54/54 [==============================] - 3s 63ms/step - loss: 0.0324 - accuracy: 0.6123 - val_loss: 0.0326 - val_accuracy: 0.6139
# Epoch 3/50
# 54/54 [==============================] - 3s 63ms/step - loss: 0.0319 - accuracy: 0.6149 - val_loss: 0.0319 - val_accuracy: 0.6100
# Epoch 4/50
# 54/54 [==============================] - 4s 66ms/step - loss: 0.0317 - accuracy: 0.6170 - val_loss: 0.0313 - val_accuracy: 0.6286
# Epoch 5/50
# 54/54 [==============================] - 4s 67ms/step - loss: 0.0316 - accuracy: 0.6198 - val_loss: 0.0309 - val_accuracy: 0.6080
# Epoch 6/50
# 54/54 [==============================] - 3s 64ms/step - loss: 0.0316 - accuracy: 0.6206 - val_loss: 0.0309 - val_accuracy: 0.6289
# Epoch 7/50
# 54/54 [==============================] - 3s 64ms/step - loss: 0.0315 - accuracy: 0.6227 - val_loss: 0.0307 - val_accuracy: 0.6230
# Epoch 8/50
# 54/54 [==============================] - 4s 68ms/step - loss: 0.0313 - accuracy: 0.6224 - val_loss: 0.0308 - val_accuracy: 0.6234
# Epoch 9/50
# 54/54 [==============================] - 4s 68ms/step - loss: 0.0314 - accuracy: 0.6199 - val_loss: 0.0312 - val_accuracy: 0.6317
# Epoch 10/50
# 54/54 [==============================] - 4s 65ms/step - loss: 0.0312 - accuracy: 0.6219 - val_loss: 0.0306 - val_accuracy: 0.6380
# Epoch 11/50
# 54/54 [==============================] - 3s 64ms/step - loss: 0.0310 - accuracy: 0.6279 - val_loss: 0.0306 - val_accuracy: 0.6183
# Epoch 12/50
# 54/54 [==============================] - 4s 65ms/step - loss: 0.0309 - accuracy: 0.6307 - val_loss: 0.0305 - val_accuracy: 0.6338
# Epoch 13/50
# 54/54 [==============================] - 4s 68ms/step - loss: 0.0307 - accuracy: 0.6368 - val_loss: 0.0306 - val_accuracy: 0.6155
# Epoch 14/50
# 54/54 [==============================] - 4s 69ms/step - loss: 0.0305 - accuracy: 0.6398 - val_loss: 0.0305 - val_accuracy: 0.6409
# Epoch 15/50
# 54/54 [==============================] - 4s 71ms/step - loss: 0.0304 - accuracy: 0.6431 - val_loss: 0.0309 - val_accuracy: 0.6489
# Epoch 16/50
# 54/54 [==============================] - 4s 71ms/step - loss: 0.0302 - accuracy: 0.6423 - val_loss: 0.0306 - val_accuracy: 0.6473
# Epoch 17/50
# 54/54 [==============================] - 4s 66ms/step - loss: 0.0300 - accuracy: 0.6475 - val_loss: 0.0306 - val_accuracy: 0.6491
# Epoch 18/50
# 54/54 [==============================] - 4s 67ms/step - loss: 0.0299 - accuracy: 0.6473 - val_loss: 0.0322 - val_accuracy: 0.6254
# Epoch 19/50
# 54/54 [==============================] - 4s 66ms/step - loss: 0.0300 - accuracy: 0.6479 - val_loss: 0.0330 - val_accuracy: 0.5976
# Epoch 20/50
# 54/54 [==============================] - 4s 65ms/step - loss: 0.0296 - accuracy: 0.6464 - val_loss: 0.0308 - val_accuracy: 0.6489
# Epoch 21/50
# 54/54 [==============================] - 3s 65ms/step - loss: 0.0291 - accuracy: 0.6522 - val_loss: 0.0323 - val_accuracy: 0.6105
# Epoch 22/50
# 54/54 [==============================] - 4s 68ms/step - loss: 0.0290 - accuracy: 0.6525 - val_loss: 0.0309 - val_accuracy: 0.6283
# Epoch 23/50
# 54/54 [==============================] - 4s 66ms/step - loss: 0.0289 - accuracy: 0.6543 - val_loss: 0.0310 - val_accuracy: 0.6445
# Epoch 24/50
# 54/54 [==============================] - 4s 66ms/step - loss: 0.0284 - accuracy: 0.6525 - val_loss: 0.0318 - val_accuracy: 0.6237
# Epoch 25/50
# 54/54 [==============================] - 3s 64ms/step - loss: 0.0287 - accuracy: 0.6528 - val_loss: 0.0304 - val_accuracy: 0.6385
# Epoch 26/50
# 54/54 [==============================] - 4s 66ms/step - loss: 0.0280 - accuracy: 0.6530 - val_loss: 0.0302 - val_accuracy: 0.6541
# Epoch 27/50
# 54/54 [==============================] - 4s 69ms/step - loss: 0.0277 - accuracy: 0.6569 - val_loss: 0.0310 - val_accuracy: 0.6123
# Epoch 28/50
# 54/54 [==============================] - 4s 65ms/step - loss: 0.0279 - accuracy: 0.6582 - val_loss: 0.0311 - val_accuracy: 0.6485
# Epoch 29/50
# 54/54 [==============================] - 3s 64ms/step - loss: 0.0275 - accuracy: 0.6546 - val_loss: 0.0310 - val_accuracy: 0.6388
# Epoch 30/50
# 54/54 [==============================] - 3s 64ms/step - loss: 0.0270 - accuracy: 0.6577 - val_loss: 0.0320 - val_accuracy: 0.6338
# Epoch 31/50
# 54/54 [==============================] - 4s 67ms/step - loss: 0.0267 - accuracy: 0.6617 - val_loss: 0.0327 - val_accuracy: 0.6319
# Epoch 32/50
# 54/54 [==============================] - 4s 67ms/step - loss: 0.0265 - accuracy: 0.6633 - val_loss: 0.0311 - val_accuracy: 0.6365
# Epoch 33/50
# 54/54 [==============================] - 3s 65ms/step - loss: 0.0264 - accuracy: 0.6596 - val_loss: 0.0320 - val_accuracy: 0.5841
# Epoch 34/50
# 54/54 [==============================] - 3s 65ms/step - loss: 0.0260 - accuracy: 0.6628 - val_loss: 0.0318 - val_accuracy: 0.6420
# Epoch 35/50
# 54/54 [==============================] - 4s 67ms/step - loss: 0.0259 - accuracy: 0.6677 - val_loss: 0.0325 - val_accuracy: 0.6009
# Epoch 36/50
# 54/54 [==============================] - 4s 68ms/step - loss: 0.0257 - accuracy: 0.6625 - val_loss: 0.0313 - val_accuracy: 0.6415
# Epoch 37/50
# 54/54 [==============================] - 4s 71ms/step - loss: 0.0253 - accuracy: 0.6685 - val_loss: 0.0311 - val_accuracy: 0.6461
# Epoch 38/50
# 54/54 [==============================] - 4s 65ms/step - loss: 0.0255 - accuracy: 0.6698 - val_loss: 0.0317 - val_accuracy: 0.6165
# Epoch 39/50
# 54/54 [==============================] - 3s 65ms/step - loss: 0.0255 - accuracy: 0.6697 - val_loss: 0.0324 - val_accuracy: 0.6241
# Epoch 40/50
# 54/54 [==============================] - 4s 68ms/step - loss: 0.0253 - accuracy: 0.6716 - val_loss: 0.0315 - val_accuracy: 0.6268
# Epoch 41/50
# 54/54 [==============================] - 4s 67ms/step - loss: 0.0247 - accuracy: 0.6744 - val_loss: 0.0315 - val_accuracy: 0.6406
# Epoch 42/50
# 54/54 [==============================] - 3s 65ms/step - loss: 0.0245 - accuracy: 0.6789 - val_loss: 0.0314 - val_accuracy: 0.6476
# Epoch 43/50
# 54/54 [==============================] - 4s 65ms/step - loss: 0.0242 - accuracy: 0.6815 - val_loss: 0.0312 - val_accuracy: 0.6267
# Epoch 44/50
# 54/54 [==============================] - 4s 66ms/step - loss: 0.0243 - accuracy: 0.6777 - val_loss: 0.0313 - val_accuracy: 0.6364
# Epoch 45/50
# 54/54 [==============================] - 4s 68ms/step - loss: 0.0250 - accuracy: 0.6763 - val_loss: 0.0353 - val_accuracy: 0.6316
# Epoch 46/50
# 54/54 [==============================] - 4s 66ms/step - loss: 0.0241 - accuracy: 0.6824 - val_loss: 0.0320 - val_accuracy: 0.6386
# Epoch 47/50
# 54/54 [==============================] - 4s 66ms/step - loss: 0.0237 - accuracy: 0.6884 - val_loss: 0.0315 - val_accuracy: 0.6350
# Epoch 48/50
# 54/54 [==============================] - 4s 73ms/step - loss: 0.0235 - accuracy: 0.6864 - val_loss: 0.0306 - val_accuracy: 0.6325
# Epoch 49/50
# 54/54 [==============================] - 5s 94ms/step - loss: 0.0230 - accuracy: 0.6888 - val_loss: 0.0314 - val_accuracy: 0.6368
# Epoch 50/50
# 54/54 [==============================] - 4s 81ms/step - loss: 0.0232 - accuracy: 0.6932 - val_loss: 0.0314 - val_accuracy: 0.6501

# %%
plt.plot(hist.history['accuracy'], label = 'accuracy')
plt.plot(hist.history['loss'], label = 'loss')
plt.plot(hist.history['val_accuracy'], label = 'val_accuracy')
plt.plot(hist.history['val_loss'], label = 'val_loss')

plt.legend(loc = 'upper left')
plt.show()
