# %% [markdown]
# <a href="https://colab.research.google.com/github/joony0512/Deep_Learning_Class/blob/main/Part5/P5_Ch02_CH02_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  System aliases

# %%
# !ls /bin
# Out:
# '['				      mpifort
#  2to3-2.7			      mpifort.openmpi
#  7z				      mpirun
#  7za				      mpirun.openmpi
#  7zr				      mtrace
#  aclocal			      mutter
#  aclocal-1.16			      mv
#  acyclic			      mysql_config
#  add-apt-repository		      namei
#  addpart			      nawk
#  addr2line			      ncal
#  apropos			      nc-config
#  apt				      ncurses5-config
#  apt-add-repository		      ncurses6-config
#  apt-cache			      ncursesw5-config
#  apt-cdrom			      ncursesw6-config
#  apt-config			      neato
#  apt-extracttemplates		      neqn
#  apt-ftparchive			      networkctl
#  apt-get			      newgrp
#  apt-key			      nice
#  apt-mark			      nisdomainname
#  apt-sortpkgs			      nl
#  ar				      nm
#  arch				      nns
#  as				      nnsd
#  asan_symbolize			      nnslog
#  asan_symbolize-10		      nohup
#  assistant			      nop
#  autoconf			      nproc
#  autoheader			      nroff
#  autom4te			      nsenter
#  automake			      nstat
#  automake-1.16			      numfmt
# ...

# %%
# !pwd
# !ls
# Out:
# /content
# drive  sample_data

# %% [markdown]
# ## 가속 하드웨어 사용하기

# %%
# !nvidia-smi #런타임 gpu로 변경 후
# Out:
# Tue Apr  4 14:26:24 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   68C    P8    11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...
